# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %run clean.ipynb
# Out:
# (25723, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
clean_data2 = clean_data.drop(columns=['Date', 'Location', 'Name', 'Age','Injury','Time', 'Species'])
clean_data2.head()
# Out:
#    Year        Type    Country             Area     Activity Sex Fatal (Y/N)
# 0  2018     Boating        USA       California     Paddling   F           N
# 1  2018  Unprovoked        USA          Georgia     Standing   F           N
# 2  2018     Invalid        USA           Hawaii      Surfing   M           N
# 3  2018  Unprovoked  AUSTRALIA  New South Wales      Surfing   M           N
# 4  2018    Provoked     MEXICO           Colima  Free diving   M           N

# %%
clean_data2=clean_data2.dropna(how='all')

# %%
#Una vez limpiados todos los datos, pretendía mostrar una gráfica que sacara en qué paises practicar surf era más 
#peligroso, pero no he sabido como plantearlo para mostrar esa gráfica.

#Tambien queria mostrar la misma gráfica para las actividades swimming y fishing, ya que me parecía que 
#podrían darnos información interesante.

# %%
sns.histplot(clean_data2["Year"]) #en esta gráfica he mostrado la cantidad de casos (globales) por año desde 1960
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.countplot(data = clean_data2, x = "Country") #en esta grafica pretendía mostrar solo los 
#países con más casos, pero no sabia como reducir esa gráfica a los 10 países con más casos, por ejemplo.
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
clean_data2['Sex'].value_counts().plot(kind='bar')
plt.xlabel('Sex')
plt.ylabel('Count') #esta gráfica muestra el numero de casos en funcion del sexo (M or F), 
#pero seguía mostrando otros valores (M o IIi) por lo que deberia haber limpiado más esa columna para quitar 
#todos los valores que no fueran Male o Female
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(data = clean_data2, x = "Type")
#en esta grafica mostramos la cantidad de ataques en funcion del tipo.
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# Personalmente, queria haber enseñado mejores gráficas pero no conseguía mostrarlas,
# las formulas me daban errores por estar mal escritas o porque las tablas no estaban completamente limpias y
# mostraba datos erroneos/incoherentes por lo que no pude llegar a conclusiones claras y siempre tenia que volver atrás para
# limpiar el dataset una y otra vez. Generalmente necesito mucho tiempo para realizar los labs, y en este proyecto
# me ha faltado tiempo para trabajar más con las gráficas, entender como funcionan y haber sacado mejores graficas/resultados. Me he visto bastante perdido y no he sabido avanzar cuando he empezado a trabajar con las gráficas.
# No estoy satisfecho con este proyecto por todo lo que he comentado anteriormente. Me está costando bastante seguir
# el ritmo de las clases porque cada dia explicais herramientas nuevas que al verlas por primera vez me cuestan asimilar, entender y ponerlas en práctica, por lo que siempre necesito más tiempo de lo normal para trabajar con ellas correctamente en los labs y en los proyectos.
