# %%
import pandas as pd

import numpy as np

#import sys
#!{sys.executable} -m pip install seaborn
import seaborn as sns

#!{sys.executable} -m pip install matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
clean_data = pd.read_csv('./output/clean_data.csv', index_col=0)
clean_data
# Out:
#         Month  Year        Type           Country                       Area  \
# 0         Jun  2018     Boating               USA                 California
# 1         Jun  2018  Unprovoked               USA                    Georgia
# 2         Jun  2018     Invalid               USA                     Hawaii
# 3         Jun  2018  Unprovoked         AUSTRALIA            New South Wales
# 4         Jun  2018    Provoked            MEXICO                     Colima
# ...       ...   ...         ...               ...                        ...
# 4029  UNKNOWN  1960  Unprovoked              FIJI     Northwest of Viti Levu
# 4030  UNKNOWN  1960  Unprovoked  PAPUA NEW GUINEA                     Madang
# 4031  UNKNOWN  1960  Unprovoked  PAPUA NEW GUINEA  West New Britain Province
# 4032  UNKNOWN  1960  Unprovoked        MOZAMBIQUE                       Gaza
# 4033  UNKNOWN  1960  Unprovoked      SOUTH AFRICA      Eastern Cape Province
#
# ...

# %%
# Showing the total amount of accidents happened on each country(Top 10).
plt.figure(figsize=(10, 8))

clean_data["Country"].value_counts().head(10).plot.bar(color = "orange");
plt.xticks(rotation=60,ha='right');

plt.title("Top ten countries with highest amount of accidents");
plt.xlabel('Country');
plt.ylabel('Count');

# %%
# Showing the total amount of accidents happened on each month since 1960.
plt.figure(figsize=(10, 8))

sns.countplot(x = clean_data["Month"], order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec", "UNKNOWN"]);

plt.xticks(rotation=60,ha='right');

plt.title("Global amount of accidents per month");
plt.xlabel('Months');
plt.ylabel('Count');

# %%
# Show attacks per month in USA, Australia and South Africa, 

plt.figure(figsize=(18,8))

plt.subplot(1,3,1) # (nrows, ncols, index)
sns.countplot(x = clean_data[clean_data["Country"] == "USA"]["Month"], order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec", "UNKNOWN"]).set_title('Accidents per month USA');
plt.xticks(rotation=60,ha='right');

plt.subplot(1,3,2) # (nrows, ncols, index)
sns.countplot(x = clean_data[clean_data["Country"] == "AUSTRALIA"]["Month"], order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec", "UNKNOWN"]).set_title('Accidents per month AUSTRALIA');
plt.xticks(rotation=60,ha='right');

plt.subplot(1,3,3) # (nrows, ncols, index)
sns.countplot(x = clean_data[clean_data["Country"] == "SOUTH AFRICA"]["Month"], order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec", "UNKNOWN"]).set_title('Accidents per month SOUTH AFRICA');
plt.xticks(rotation=60,ha='right');

#UNKNOWN COLUMN COULD BE OMITTED IN THE VISUALIZATIONS IF WE JUST REMOVE IT FROM "ORDER".

# %%
# showing if the global accidents since 1960 (divided by months) where fatal or not.
sns.countplot(x=clean_data.Month, hue=clean_data["Fatal (Y/N)"], order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec", "UNKNOWN"]);
plt.xticks(rotation=60,ha='right');

# %%
# Ideally wanted to show the Top 10 countries with the highest number of "fatal accidents = Yes", but the code is showing all the Fatal Y/N accidents instead of only the "Y"....

sns.countplot(data = clean_data[clean_data["Fatal (Y/N)"] == "Y"], x = clean_data["Country"], order = clean_data["Country"].value_counts().iloc[:10].index);
plt.xticks(rotation = 60,ha ='right');

# %%
#showing the Top 10 countries with highest amount of Fatal (Y/N) records.

sns.countplot(x = clean_data.Country, hue = clean_data["Fatal (Y/N)"], order = clean_data["Country"].value_counts().iloc[:10].index);
plt.xticks(rotation = 60,ha = 'right');

# %%
# showing the total amount of cases since 1960 per year.
sns.histplot(clean_data["Year"]);

# %%
# Amount of accidents since 1960 on TOP3 Countries.
plt.figure(figsize=(15,5))

plt.subplot(1,3,1) # (nrows, ncols, index)
sns.histplot(clean_data[clean_data["Country"] == "USA"]["Year"]).set_title('USA - Amount of accidents since 1960');

plt.subplot(1,3,2) # (nrows, ncols, index)
sns.histplot(clean_data[clean_data["Country"] == "AUSTRALIA"]["Year"]).set_title('AUSTRALIA - Amount of accidents since 1960');

plt.subplot(1,3,3) # (nrows, ncols, index)
sns.histplot(clean_data[clean_data["Country"] == "SOUTH AFRICA"]["Year"]).set_title('SOUTH AFRICA - Amount of accidents since 1960');

# %%
# esta gráfica muestra el numero de casos en funcion del sexo (M or F)
clean_data['Sex'].value_counts().plot(kind='bar');
plt.xlabel('Sex');
plt.ylabel('Count');

# %%
#en esta grafica mostramos los tipos de accidente.
sns.countplot(data = clean_data, x = "Type")

plt.xticks(rotation=60,ha='right');
plt.title("Type of accidents");
plt.xlabel('Type');
plt.ylabel('Count');

# %%
#PIE-CHART ERROR!!!!!!!!!!!!!!!


#clean_data["Fatal (Y/N)"].plot.pie(autopct='%1.0f%%',explode=[0.1], shadow=True, subplots=True,  figsize=[10,6])
#clean_data["Sex"].plot.pie(autopct="%.1f%%");
#plot = clean_data.plot.pie(y='Fatal (Y/N)', figsize=(5, 5))
#clean_data["Fatal (Y/N)"].value_counts()

# %%
clean_data = clean_data[clean_data["Fatal (Y/N)"] != "2017"] # To remove any value called "2017"
clean_data["Fatal (Y/N)"].value_counts()
# Out:
# N          3170
# Y           495
# UNKNOWN     368
# Name: Fatal (Y/N), dtype: int64

# %%
clean_data.Species.unique()
# Out:
# array(['White shark', nan, '2 m shark', ...,
#        "3.7 m to 4.6 m [12' to 15'] shark", 'Blacktail reef shark',
#        'Blacktip reef shark'], dtype=object)

# %%
clean_data.Species.value_counts()
# Out:
# White shark                                            135
# Shark involvement prior to death was not confirmed      82
# Shark involvement not confirmed                         81
# Invalid                                                 61
# Tiger shark                                             54
#                                                       ...
# Bronze whaler shark, 1.5 m [5']                          1
# 1.2 m to 1.5 m [4' to 5'] "reef shark"                   1
# Two 1.2 m to 1.5 m [4' to 5'] sharks                     1
# Longfin mako shark, 3.5 m [11.5'], 350-kg [772-lb]       1
# Bronze whaler shark, 3m                                  1
# Name: Species, Length: 1228, dtype: int64

# %%
# Hist plot "Age" to find out which is the most repeated age when the accident happened.

plt.figure(figsize=(10, 8))

clean_data["Age"].value_counts().head(25).plot.bar(color = "orange");
plt.xticks(rotation=60,ha='right');

plt.title("Most repeated age when the accident happened");
plt.xlabel('Age');
plt.ylabel('Count');

#plt.savefig("Most repeated age when the accident happened.png")
# si queremos imprimir el fondo transparente, añadir transparent=True al código. plt.savefig("Most repeated age when the accident happened.png", transparent=True)

# %%
sns.countplot(x=clean_data.Age, palette = "Greens")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Top 5 Types of accident in USA, 
# Month of the year when most of the accidents happened in USA, 
# TOP5 activities when accidents happened in USA, adding algo the SEX to discover which of these accidents happened to Men or Women.

# %%
clean_data
# Out:
#      Month  Year        Type           Country                       Area  \
# 0      Jun  2018     Boating               USA                 California
# 1      Jun  2018  Unprovoked               USA                    Georgia
# 2      Jun  2018     Invalid               USA                     Hawaii
# 3      Jun  2018  Unprovoked         AUSTRALIA            New South Wales
# 4      Jun  2018    Provoked            MEXICO                     Colima
# ...    ...   ...         ...               ...                        ...
# 4029   NaN  1960  Unprovoked              FIJI     Northwest of Viti Levu
# 4030   NaN  1960  Unprovoked  PAPUA NEW GUINEA                     Madang
# 4031   NaN  1960  Unprovoked  PAPUA NEW GUINEA  West New Britain Province
# 4032    Ca  1960  Unprovoked        MOZAMBIQUE                       Gaza
# 4033    Ca  1960  Unprovoked      SOUTH AFRICA      Eastern Cape Province
#
#                             Location                           Activity Sex  \
# ...
